# %% [markdown]
# # EDA on Loan Defaulters Data

# %% [markdown]
# ## Phases
# * Phase 1 - Fill missing values and fix individual columns
# * Phase 2 - Understand distributions
# * Phase 3 - Analyze relationships
# * Phase 4 - Let's see

# %% [markdown]
# ## Phase 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, math
from pathlib import Path

# %%
df = pd.read_csv("../data/processed/dataset_cleaned_v1.csv")

# %%
df['ID'] = df['ID'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID                             121856 non-null  object
#  1   Client_Income                  121856 non-null  float64
#  2   Car_Owned                      121856 non-null  float64
#  3   Bike_Owned                     121856 non-null  float64
#  4   Active_Loan                    121856 non-null  float64
#  5   House_Own                      121856 non-null  float64
#  6   Child_Count                    121856 non-null  float64
#  7   Credit_Amount                  121856 non-null  float64
#  8   Loan_Annuity                   121856 non-null  float64
#  9   Accompany_Client               121856 non-null  object
#  10  Client_Income_Type             121856 non-null  object
#  11  Client_Education               121856 non-null  object
#  12  Client_Marital_Status          121856 non-null  object
#  13  Client_Gender                  121856 non-null  object
#  14  Loan_Contract_Type             121856 non-null  object
#  15  Client_Housing_Type            121856 non-null  object
#  16  Population_Region_Relative     121856 non-null  float64
#  17  Age_Days                       121856 non-null  float64
#  18  Employed_Days                  121856 non-null  float64
#  19  Registration_Days              121856 non-null  float64
#  20  ID_Days                        121856 non-null  float64
#  21  Own_House_Age                  121856 non-null  float64
#  22  Mobile_Tag                     121856 non-null  int64
#  23  Homephone_Tag                  121856 non-null  int64
#  24  Workphone_Working              121856 non-null  int64
#  25  Client_Occupation              121856 non-null  object
#  26  Client_Family_Members          121856 non-null  float64
#  27  Client_City_Rating             121856 non-null  float64
#  28  Application_Process_Day        121856 non-null  float64
#  29  Application_Process_Hour       121856 non-null  float64
#  30  Client_Permanent_Match_Tag     121856 non-null  object
#  31  Client_Contact_Work_Tag        121856 non-null  object
#  32  Type_Organization              121856 non-null  object
#  33  Score_Source_1                 121856 non-null  float64
#  34  Score_Source_2                 121856 non-null  float64
#  35  Score_Source_3                 121856 non-null  float64
#  36  Social_Circle_Default          121856 non-null  float64
#  37  Phone_Change                   121856 non-null  float64
#  38  Credit_Bureau                  121856 non-null  float64
#  39  Default                        121856 non-null  int64
#  40  Own_House_Age_Missing          121856 non-null  int64
#  41  Score_Source_1_missing         121856 non-null  int64
#  42  Social_Circle_Default_missing  121856 non-null  int64
#  43  Score_Source_3_missing         121856 non-null  int64
#  44  Credit_Bureau_missing          121856 non-null  int64
# dtypes: float64(24), int64(9), object(12)
# memory usage: 41.8+ MB

# %%
for col in df.columns:
    dtype = df[col].dtype
    nunique = df[col].nunique(dropna=True)
    
    print(f"{col}  |  dtype: {dtype}  |  unique: {nunique}")
    
    if nunique < 5:
        print("   → Unique values:", df[col].unique())
    
    print("-" * 60)
# Out:
# ID  |  dtype: object  |  unique: 121856
# ------------------------------------------------------------
# Client_Income  |  dtype: float64  |  unique: 1217
# ------------------------------------------------------------
# Car_Owned  |  dtype: float64  |  unique: 2
#    → Unique values: [0. 1.]
# ------------------------------------------------------------
# Bike_Owned  |  dtype: float64  |  unique: 2
#    → Unique values: [0. 1.]
# ------------------------------------------------------------
# Active_Loan  |  dtype: float64  |  unique: 2
#    → Unique values: [1. 0.]
# ------------------------------------------------------------
# House_Own  |  dtype: float64  |  unique: 2
#    → Unique values: [0. 1.]
# ------------------------------------------------------------
# Child_Count  |  dtype: float64  |  unique: 15
# ------------------------------------------------------------
# Credit_Amount  |  dtype: float64  |  unique: 4176
# ------------------------------------------------------------
# Loan_Annuity  |  dtype: float64  |  unique: 10857
# ------------------------------------------------------------
# Accompany_Client  |  dtype: object  |  unique: 7
# ------------------------------------------------------------
# Client_Income_Type  |  dtype: object  |  unique: 8
# ------------------------------------------------------------
# Client_Education  |  dtype: object  |  unique: 5
# ------------------------------------------------------------
# Client_Marital_Status  |  dtype: object  |  unique: 4
#    → Unique values: ['M' 'W' 'S' 'D']
# ------------------------------------------------------------
# Client_Gender  |  dtype: object  |  unique: 3
#    → Unique values: ['Male' 'Female' 'XNA']
# ------------------------------------------------------------
# Loan_Contract_Type  |  dtype: object  |  unique: 2
#    → Unique values: ['CL' 'RL']
# ------------------------------------------------------------
# Client_Housing_Type  |  dtype: object  |  unique: 6
# ------------------------------------------------------------
# Population_Region_Relative  |  dtype: float64  |  unique: 82
# ------------------------------------------------------------
# Age_Days  |  dtype: float64  |  unique: 17001
# ------------------------------------------------------------
# Employed_Days  |  dtype: float64  |  unique: 9950
# ------------------------------------------------------------
# Registration_Days  |  dtype: float64  |  unique: 14143
# ------------------------------------------------------------
# ID_Days  |  dtype: float64  |  unique: 5963
# ------------------------------------------------------------
# Own_House_Age  |  dtype: float64  |  unique: 55
# ------------------------------------------------------------
# Mobile_Tag  |  dtype: int64  |  unique: 2
#    → Unique values: [1 0]
# ------------------------------------------------------------
# Homephone_Tag  |  dtype: int64  |  unique: 2
#    → Unique values: [1 0]
# ------------------------------------------------------------
# Workphone_Working  |  dtype: int64  |  unique: 2
#    → Unique values: [0 1]
# ------------------------------------------------------------
# Client_Occupation  |  dtype: object  |  unique: 19
# ------------------------------------------------------------
# Client_Family_Members  |  dtype: float64  |  unique: 16
# ------------------------------------------------------------
# Client_City_Rating  |  dtype: float64  |  unique: 4
#    → Unique values: [2.         3.         1.         2.03003843]
# ------------------------------------------------------------
# Application_Process_Day  |  dtype: float64  |  unique: 8
# ------------------------------------------------------------
# Application_Process_Hour  |  dtype: float64  |  unique: 25
# ------------------------------------------------------------
# Client_Permanent_Match_Tag  |  dtype: object  |  unique: 2
#    → Unique values: ['Yes' 'No']
# ------------------------------------------------------------
# Client_Contact_Work_Tag  |  dtype: object  |  unique: 2
#    → Unique values: ['Yes' 'No']
# ------------------------------------------------------------
# Type_Organization  |  dtype: object  |  unique: 58
# ------------------------------------------------------------
# Score_Source_1  |  dtype: float64  |  unique: 43968
# ------------------------------------------------------------
# Score_Source_2  |  dtype: float64  |  unique: 67017
# ------------------------------------------------------------
# Score_Source_3  |  dtype: float64  |  unique: 771
# ------------------------------------------------------------
# Social_Circle_Default  |  dtype: float64  |  unique: 1882
# ------------------------------------------------------------
# Phone_Change  |  dtype: float64  |  unique: 3591
# ------------------------------------------------------------
# Credit_Bureau  |  dtype: float64  |  unique: 21
# ------------------------------------------------------------
# Default  |  dtype: int64  |  unique: 2
#    → Unique values: [0 1]
# ------------------------------------------------------------
# Own_House_Age_Missing  |  dtype: int64  |  unique: 2
#    → Unique values: [1 0]
# ------------------------------------------------------------
# Score_Source_1_missing  |  dtype: int64  |  unique: 2
#    → Unique values: [0 1]
# ------------------------------------------------------------
# Social_Circle_Default_missing  |  dtype: int64  |  unique: 2
#    → Unique values: [0 1]
# ------------------------------------------------------------
# Score_Source_3_missing  |  dtype: int64  |  unique: 2
#    → Unique values: [1 0]
# ------------------------------------------------------------
# Credit_Bureau_missing  |  dtype: int64  |  unique: 2
#    → Unique values: [1 0]
# ------------------------------------------------------------

# %%
# replace 'XNA' in Client_Gender with Mode
mode_gender = df['Client_Gender'].mode()[0]
df['Client_Gender'] = df['Client_Gender'].replace('XNA', mode_gender)

# encode binary columns
binary_cols = [col for col in df.columns if df[col].nunique(dropna=True) == 2]

# convert all binary columns except 'Default' to Category
for col in binary_cols:
    if col == 'Default':
        continue
    
    # If binary column is object/string, convert to 0/1
    if df[col].dtype == object or df[col].dtype.name == "category":
        # Map unique values to 0/1 consistently
        unique_vals = list(df[col].dropna().unique())
        mapping = {unique_vals[0]: 0, unique_vals[1]: 1}
        df[col] = df[col].map(mapping)
    
    # Convert to int if bool-like
    df[col] = df[col].astype(int)

    df[col] = df[col].astype('category')

# %% [markdown]
# ### I would like to find which columns are ordinal and which are nominal
# * Can't just say - numeric -> ordinal and categorical -> nominal

# %%
cardinality = df.nunique().sort_values()
cardinality
# Out:
# Bike_Owned                            2
# Car_Owned                             2
# House_Own                             2
# Active_Loan                           2
# Client_Gender                         2
# Loan_Contract_Type                    2
# Homephone_Tag                         2
# Mobile_Tag                            2
# Workphone_Working                     2
# Client_Contact_Work_Tag               2
# Client_Permanent_Match_Tag            2
# Score_Source_3_missing                2
# Credit_Bureau_missing                 2
# Score_Source_1_missing                2
# Social_Circle_Default_missing         2
# Default                               2
# Own_House_Age_Missing                 2
# Client_City_Rating                    4
# Client_Marital_Status                 4
# Client_Education                      5
# Client_Housing_Type                   6
# Accompany_Client                      7
# Application_Process_Day               8
# Client_Income_Type                    8
# Child_Count                          15
# Client_Family_Members                16
# Client_Occupation                    19
# Credit_Bureau                        21
# Application_Process_Hour             25
# Own_House_Age                        55
# Type_Organization                    58
# Population_Region_Relative           82
# Score_Source_3                      771
# Client_Income                      1217
# Social_Circle_Default              1882
# Phone_Change                       3591
# Credit_Amount                      4176
# ID_Days                            5963
# Employed_Days                      9950
# Loan_Annuity                      10857
# Registration_Days                 14143
# Age_Days                          17001
# Score_Source_1                    43968
# Score_Source_2                    67017
# ID                               121856
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID                             121856 non-null  object
#  1   Client_Income                  121856 non-null  float64
#  2   Car_Owned                      121856 non-null  category
#  3   Bike_Owned                     121856 non-null  category
#  4   Active_Loan                    121856 non-null  category
#  5   House_Own                      121856 non-null  category
#  6   Child_Count                    121856 non-null  float64
#  7   Credit_Amount                  121856 non-null  float64
#  8   Loan_Annuity                   121856 non-null  float64
#  9   Accompany_Client               121856 non-null  object
#  10  Client_Income_Type             121856 non-null  object
#  11  Client_Education               121856 non-null  object
#  12  Client_Marital_Status          121856 non-null  object
#  13  Client_Gender                  121856 non-null  category
#  14  Loan_Contract_Type             121856 non-null  category
#  15  Client_Housing_Type            121856 non-null  object
#  16  Population_Region_Relative     121856 non-null  float64
#  17  Age_Days                       121856 non-null  float64
#  18  Employed_Days                  121856 non-null  float64
#  19  Registration_Days              121856 non-null  float64
#  20  ID_Days                        121856 non-null  float64
#  21  Own_House_Age                  121856 non-null  float64
#  22  Mobile_Tag                     121856 non-null  category
#  23  Homephone_Tag                  121856 non-null  category
#  24  Workphone_Working              121856 non-null  category
#  25  Client_Occupation              121856 non-null  object
#  26  Client_Family_Members          121856 non-null  float64
#  27  Client_City_Rating             121856 non-null  float64
#  28  Application_Process_Day        121856 non-null  float64
#  29  Application_Process_Hour       121856 non-null  float64
#  30  Client_Permanent_Match_Tag     121856 non-null  category
#  31  Client_Contact_Work_Tag        121856 non-null  category
#  32  Type_Organization              121856 non-null  object
#  33  Score_Source_1                 121856 non-null  float64
#  34  Score_Source_2                 121856 non-null  float64
#  35  Score_Source_3                 121856 non-null  float64
#  36  Social_Circle_Default          121856 non-null  float64
#  37  Phone_Change                   121856 non-null  float64
#  38  Credit_Bureau                  121856 non-null  float64
#  39  Default                        121856 non-null  int64
#  40  Own_House_Age_Missing          121856 non-null  category
#  41  Score_Source_1_missing         121856 non-null  category
#  42  Social_Circle_Default_missing  121856 non-null  category
#  43  Score_Source_3_missing         121856 non-null  category
#  44  Credit_Bureau_missing          121856 non-null  category
# dtypes: category(16), float64(20), int64(1), object(8)
# memory usage: 28.8+ MB

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
numeric_cols.remove('Default')
categorical_cols.remove('ID')

# %%
print("Numeric Columns:", numeric_cols)
print("Categorical Columns:", categorical_cols)
# Out:
# Numeric Columns: ['Client_Income', 'Child_Count', 'Credit_Amount', 'Loan_Annuity', 'Population_Region_Relative', 'Age_Days', 'Employed_Days', 'Registration_Days', 'ID_Days', 'Own_House_Age', 'Client_Family_Members', 'Client_City_Rating', 'Application_Process_Day', 'Application_Process_Hour', 'Score_Source_1', 'Score_Source_2', 'Score_Source_3', 'Social_Circle_Default', 'Phone_Change', 'Credit_Bureau']
# Categorical Columns: ['Car_Owned', 'Bike_Owned', 'Active_Loan', 'House_Own', 'Accompany_Client', 'Client_Income_Type', 'Client_Education', 'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type', 'Client_Housing_Type', 'Mobile_Tag', 'Homephone_Tag', 'Workphone_Working', 'Client_Occupation', 'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag', 'Type_Organization', 'Own_House_Age_Missing', 'Score_Source_1_missing', 'Social_Circle_Default_missing', 'Score_Source_3_missing', 'Credit_Bureau_missing']

# %% [markdown]
# ### Univariate Analysis
# What is the distribution, behavior, and quality of EACH feature on its own?

# %% [markdown]
# #### Numerical Features

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"{col} — Distribution")
    plt.show()

# %% [markdown]
# #### Need to cap some columns

# %%
df['Child_Count'] = df['Child_Count'].clip(upper=8)
df['Credit_Amount'] = df['Credit_Amount'].clip(upper=df['Credit_Amount'].quantile(0.995))

# Convert negative to positive
df['Employed_Days'] = df['Employed_Days'].abs()

# Cap at 40 years
df['Employed_Days'] = df['Employed_Days'].clip(upper=365 * 40)

# %%
# bin house age
df['Own_House_Age_bin'] = pd.cut(
    df['Own_House_Age'],
    bins=[0, 1, 5, 10, 20, 50, 100],
    labels=['none/unknown','0-5','5-10','10-20','20-50','50+']
)

# %%
for col in ['Child_Count', 'Employed_Days', 'Own_House_Age_bin']:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"{col} — Distribution")
    plt.show()

# %% [markdown]
# ### Categorical Features

# %%
print(categorical_cols)
print(len(categorical_cols))
# Out:
# ['Car_Owned', 'Bike_Owned', 'Active_Loan', 'House_Own', 'Accompany_Client', 'Client_Income_Type', 'Client_Education', 'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type', 'Client_Housing_Type', 'Mobile_Tag', 'Homephone_Tag', 'Workphone_Working', 'Client_Occupation', 'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag', 'Type_Organization', 'Own_House_Age_Missing', 'Score_Source_1_missing', 'Social_Circle_Default_missing', 'Score_Source_3_missing', 'Credit_Bureau_missing']
# 23

# %%
for col in categorical_cols:
    plt.figure(figsize=(6,4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f"{col} — Value Counts")
    plt.show()

# %% [markdown]
# #### Talking points
# * Mobile_Tag - very few zeroes. Can't help modelling. Drop the column
# * Default - obviously imbalanced
# * Accompany_Client - Replace '##', Combine rare classes (Kids, Others, Group)
# * Client_Income_client - Combine rare classes

# %%
df.drop(['Mobile_Tag'], inplace=True, axis=1)

# %%
df = df[df['Client_Gender'] != "XNA"].copy()

# %%
rare_accompany = ['Kids','Others','Group', '##']
df.loc[:,'Accompany_Client'] = df.loc[:,'Accompany_Client'].replace(rare_accompany, "Other")

# %%
rare_income = ['Student','Unemployed','Maternity leave','Businessman']
df.loc[:,'Client_Income_Type'] = df['Client_Income_Type'].replace(rare_income, "Other")

# %%
for col in ['Accompany_Client', 'Client_Income_Type']:
    plt.figure(figsize=(6,4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f"{col} — Value Counts")
    plt.show()

# %%
os.makedirs("../data/processed", exist_ok=True)
df.to_csv("../data/processed/dataset_cleaned_v2.csv", index=False)

# %% [markdown]
# ## Phase 3

# %% [markdown]
# ### Bivariate Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("../data/processed/dataset_cleaned_v2.csv")

# %%
df['ID'] = df['ID'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ID                             121856 non-null  object
#  1   Client_Income                  121856 non-null  float64
#  2   Car_Owned                      121856 non-null  int64
#  3   Bike_Owned                     121856 non-null  int64
#  4   Active_Loan                    121856 non-null  int64
#  5   House_Own                      121856 non-null  int64
#  6   Child_Count                    121856 non-null  float64
#  7   Credit_Amount                  121856 non-null  float64
#  8   Loan_Annuity                   121856 non-null  float64
#  9   Accompany_Client               121856 non-null  object
#  10  Client_Income_Type             121856 non-null  object
#  11  Client_Education               121856 non-null  object
#  12  Client_Marital_Status          121856 non-null  object
#  13  Client_Gender                  121856 non-null  int64
#  14  Loan_Contract_Type             121856 non-null  int64
#  15  Client_Housing_Type            121856 non-null  object
#  16  Population_Region_Relative     121856 non-null  float64
#  17  Age_Days                       121856 non-null  float64
#  18  Employed_Days                  121856 non-null  float64
#  19  Registration_Days              121856 non-null  float64
#  20  ID_Days                        121856 non-null  float64
#  21  Own_House_Age                  121856 non-null  float64
#  22  Homephone_Tag                  121856 non-null  int64
#  23  Workphone_Working              121856 non-null  int64
#  24  Client_Occupation              121856 non-null  object
#  25  Client_Family_Members          121856 non-null  float64
#  26  Client_City_Rating             121856 non-null  float64
#  27  Application_Process_Day        121856 non-null  float64
#  28  Application_Process_Hour       121856 non-null  float64
#  29  Client_Permanent_Match_Tag     121856 non-null  int64
#  30  Client_Contact_Work_Tag        121856 non-null  int64
#  31  Type_Organization              121856 non-null  object
#  32  Score_Source_1                 121856 non-null  float64
#  33  Score_Source_2                 121856 non-null  float64
#  34  Score_Source_3                 121856 non-null  float64
#  35  Social_Circle_Default          121856 non-null  float64
#  36  Phone_Change                   121856 non-null  float64
#  37  Credit_Bureau                  121856 non-null  float64
#  38  Default                        121856 non-null  int64
#  39  Own_House_Age_Missing          121856 non-null  int64
#  40  Score_Source_1_missing         121856 non-null  int64
#  41  Social_Circle_Default_missing  121856 non-null  int64
#  42  Score_Source_3_missing         121856 non-null  int64
#  43  Credit_Bureau_missing          121856 non-null  int64
#  44  Own_House_Age_bin              40902 non-null   object
# dtypes: float64(20), int64(16), object(9)
# memory usage: 41.8+ MB

# %% [markdown]
# #### Numerical features vs target

# %%
for col in numeric_cols:
    print(f"\n==== {col} ====")
    print(df.groupby('Default')[col].median())

    fig, axes = plt.subplots(1, 2, figsize=(12,4))

    # KDE distributions
    sns.kdeplot(data=df, x=col, hue='Default', ax=axes[0], fill=True)
    axes[0].set_title(f"{col} — KDE by Default")

    # Boxplot
    sns.boxplot(x='Default', y=col, data=df, ax=axes[1])
    axes[1].set_title(f"{col} — Boxplot by Default")

    plt.show()
# Out:
# ==== Client_Income ====
# Default
# 0    15750.0
# 1    14400.0
# Name: Client_Income, dtype: float64
# ==== Child_Count ====
# Default
# 0    0.0
# 1    0.0
# Name: Child_Count, dtype: float64
# ==== Credit_Amount ====
# Default
# 0    52649.1
# 1    50940.0
# Name: Credit_Amount, dtype: float64
# ==== Loan_Annuity ====
# Default
# 0    2559.15
# 1    2572.65
# Name: Loan_Annuity, dtype: float64
# ==== Population_Region_Relative ====
# Default
# 0    0.019101
# 1    0.018801
# Name: Population_Region_Relative, dtype: float64
# ==== Age_Days ====
# Default
# 0    16027.422948
# 1    14582.000000
# Name: Age_Days, dtype: float64
# ==== Employed_Days ====
# Default
# 0    2406.0
# 1    1518.0
# Name: Employed_Days, dtype: float64
# ==== Registration_Days ====
# Default
# 0    4667.0
# 1    4184.0
# Name: Registration_Days, dtype: float64
# ==== ID_Days ====
# Default
# 0    3128.0
# 1    2940.0
# Name: ID_Days, dtype: float64
# ==== Own_House_Age ====
# Default
# 0    0.0
# 1    0.0
# Name: Own_House_Age, dtype: float64
# ==== Client_Family_Members ====
# Default
# 0    2.0
# 1    2.0
# Name: Client_Family_Members, dtype: float64
# ==== Client_City_Rating ====
# Default
# 0    2.0
# 1    2.0
# Name: Client_City_Rating, dtype: float64
# ==== Application_Process_Day ====
# Default
# 0    3.0
# 1    3.0
# Name: Application_Process_Day, dtype: float64
# ==== Application_Process_Hour ====
# Default
# 0    12.0
# 1    12.0
# Name: Application_Process_Hour, dtype: float64
# ==== Score_Source_1 ====
# Default
# 0    0.504657
# 1    0.504657
# Name: Score_Source_1, dtype: float64
# ==== Score_Source_2 ====
# Default
# 0    0.561212
# 1    0.458804
# Name: Score_Source_2, dtype: float64
# ==== Score_Source_3 ====
# Default
# 0    0.53707
# 1    0.49206
# Name: Score_Source_3, dtype: float64
# ==== Social_Circle_Default ====
# Default
# 0    0.0
# 1    0.0
# Name: Social_Circle_Default, dtype: float64
# ==== Phone_Change ====
# Default
# 0    814.0
# 1    617.0
# Name: Phone_Change, dtype: float64
# ==== Credit_Bureau ====
# Default
# 0    1.0
# 1    1.0
# Name: Credit_Bureau, dtype: float64

# %% [markdown]
# client income, population region relative, score_source_2 are heavily skewed

# %%
df['Client_Income_log'] = np.log1p(df['Client_Income'])
df['Client_Income'] = df['Client_Income'].clip(upper=df['Client_Income'].quantile(0.995))

# %%
df['Population_Region_Relative'] = df['Population_Region_Relative'].clip(lower=1e-6, 
                                                                         upper=df['Population_Region_Relative'].quantile(0.995))
df['Population_Region_Relative_log'] = np.log1p(df['Population_Region_Relative'])

# %%
df['Score_Source_2'] = df['Score_Source_2'].clip(upper=df['Score_Source_2'].quantile(0.995))

# %% [markdown]
# ##### Ran the above plots again :)

# %% [markdown]
# #### Categorical Columns

# %%
categorical_cols = [x for x in categorical_cols if x not in ["Mobile_Tag", "Default"]]
print(categorical_cols)
# Out:
# ['Car_Owned', 'Bike_Owned', 'Active_Loan', 'House_Own', 'Accompany_Client', 'Client_Income_Type', 'Client_Education', 'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type', 'Client_Housing_Type', 'Homephone_Tag', 'Workphone_Working', 'Client_Occupation', 'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag', 'Type_Organization', 'Own_House_Age_Missing', 'Score_Source_1_missing', 'Social_Circle_Default_missing', 'Score_Source_3_missing', 'Credit_Bureau_missing']

# %%
for col in categorical_cols:
    print(f"\n==================== {col} ====================")
    
    # Default rate table
    temp = df.groupby(col)['Default'].mean().sort_values(ascending=False)
    print(temp)
    
    # Frequency table
    print("\nCounts:")
    print(df[col].value_counts())
    
    # Plot default rate
    plt.figure(figsize=(10,4))
    sns.barplot(x=temp.index, y=temp.values)
    plt.title(f"Default Rate by {col}")
    plt.ylabel("Default Rate")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ==================== Car_Owned ====================
# Car_Owned
# 0    0.085136
# 1    0.072082
# Name: Default, dtype: float64
#
# Counts:
# Car_Owned
# 0    81305
# 1    40551
# Name: count, dtype: int64
# ==================== Bike_Owned ====================
# Bike_Owned
# 0    0.080875
# 1    0.080618
# Name: Default, dtype: float64
#
# Counts:
# Bike_Owned
# 0    82572
# 1    39284
# Name: count, dtype: int64
# ==================== Active_Loan ====================
# Active_Loan
# 1    0.080813
# 0    0.080773
# Name: Default, dtype: float64
#
# Counts:
# Active_Loan
# 0    62843
# 1    59013
# Name: count, dtype: int64
# ==================== House_Own ====================
# House_Own
# 0    0.081051
# 1    0.080682
# Name: Default, dtype: float64
#
# Counts:
# House_Own
# 1    85459
# 0    36397
# Name: count, dtype: int64
# ==================== Accompany_Client ====================
# Accompany_Client
# Alone       0.082013
# Partner     0.079274
# Other       0.075503
# Relative    0.074359
# Name: Default, dtype: float64
#
# Counts:
# Accompany_Client
# Alone       99155
# Relative    15748
# Partner      4516
# Other        2437
# Name: count, dtype: int64
# ==================== Client_Income_Type ====================
# Client_Income_Type
# Other         0.176471
# Service       0.094007
# Commercial    0.075890
# Govt Job      0.058292
# Retired       0.055410
# Name: Default, dtype: float64
#
# Counts:
# Client_Income_Type
# Service       64729
# Commercial    27764
# Retired       21043
# Govt Job       8303
# Other            17
# Name: count, dtype: int64
# ==================== Client_Education ====================
# Client_Education
# Junior secondary      0.105155
# Secondary             0.090205
# Graduation dropout    0.082828
# Graduation            0.050835
# Post Grad             0.015152
# Name: Default, dtype: float64
#
# Counts:
# Client_Education
# Secondary             87556
# Graduation            28819
# Graduation dropout     3960
# Junior secondary       1455
# Post Grad                66
# Name: count, dtype: int64
# ==================== Client_Marital_Status ====================
# Client_Marital_Status
# S    0.096989
# M    0.079067
# D    0.077290
# W    0.064537
# Name: Default, dtype: float64
#
# Counts:
# Client_Marital_Status
# M    90822
# S    17404
# D     7556
# W     6074
# Name: count, dtype: int64
# ==================== Client_Gender ====================
# Client_Gender
# 1    0.100154
# 0    0.070983
# Name: Default, dtype: float64
#
# Counts:
# Client_Gender
# 0    80879
# 1    40977
# Name: count, dtype: int64
# ==================== Loan_Contract_Type ====================
# Loan_Contract_Type
# 0    0.083128
# 1    0.057455
# Name: Default, dtype: float64
#
# Counts:
# Loan_Contract_Type
# 0    110769
# 1     11087
# Name: count, dtype: int64
# ==================== Client_Housing_Type ====================
# Client_Housing_Type
# Rental       0.126101
# Family       0.112398
# Shared       0.100000
# Municipal    0.088748
# Home         0.078079
# Office       0.067864
# Name: Default, dtype: float64
#
# Counts:
# Client_Housing_Type
# Home         108557
# Family         5783
# Municipal      4248
# Rental         1816
# Office         1002
# Shared          450
# Name: count, dtype: int64
# ==================== Homephone_Tag ====================
# Homephone_Tag
# 1    0.092543
# 0    0.077845
# Name: Default, dtype: float64
#
# Counts:
# Homephone_Tag
# 0    97424
# 1    24432
# Name: count, dtype: int64
# ==================== Workphone_Working ====================
# Workphone_Working
# 0    0.085170
# 1    0.069603
# Name: Default, dtype: float64
#
# Counts:
# Workphone_Working
# 0    87590
# 1    34266
# Name: count, dtype: int64
# ==================== Client_Occupation ====================
# Client_Occupation
# Low-skill Laborers    0.171537
# Security              0.112933
# Cooking               0.111960
# Drivers               0.110490
# Laborers              0.104595
# Waiters/barmen        0.099804
# Sales                 0.097643
# Cleaning              0.094077
# IT                    0.081633
# Realty agents         0.075000
# Medicine              0.072509
# Private service       0.070577
# Secretaries           0.069680
# Unknown               0.067503
# Core                  0.061540
# Managers              0.060501
# High skill tech       0.056057
# Accountants           0.053903
# HR                    0.053398
# Name: Default, dtype: float64
#
# Counts:
# Client_Occupation
# Unknown               41435
# Laborers              21024
# Sales                 12136
# Core                  10611
# Managers               8099
# Drivers                7150
# High skill tech        4317
# Accountants            3766
# Medicine               3172
# Security               2683
# Cooking                2224
# Cleaning               1722
# Private service        1006
# Low-skill Laborers      787
# Secretaries             531
# Waiters/barmen          511
# Realty agents           280
# HR                      206
# IT                      196
# Name: count, dtype: int64
# ==================== Client_Permanent_Match_Tag ====================
# Client_Permanent_Match_Tag
# 1    0.120825
# 0    0.077445
# Name: Default, dtype: float64
#
# Counts:
# Client_Permanent_Match_Tag
# 0    112454
# 1      9402
# Name: count, dtype: int64
# ==================== Client_Contact_Work_Tag ====================
# Client_Contact_Work_Tag
# 1    0.097111
# 0    0.077228
# Name: Default, dtype: float64
#
# Counts:
# Client_Contact_Work_Tag
# 0    100015
# 1     21841
# Name: count, dtype: int64
# ==================== Type_Organization ====================
# Type_Organization
# Trade: type 5             0.250000
# Industry: type 8          0.200000
# Transport: type 3         0.147705
# Emergency                 0.125604
# Construction              0.122760
# Industry: type 4          0.121662
# Cleaning                  0.118644
# Agriculture               0.115727
# Restaurant                0.114085
# Industry: type 1          0.112219
# Security                  0.109813
# Transport: type 4         0.103083
# Self-employed             0.101596
# Legal Services            0.100840
# Trade: type 3             0.100149
# Industry: type 10         0.100000
# Industry: type 3          0.098785
# Industry: type 11         0.091091
# Trade: type 7             0.090634
# Business Entity Type 3    0.090337
# Business Entity Type 1    0.089927
# Realtor                   0.089744
# Industry: type 13         0.085714
# Culture                   0.083969
# Postal                    0.083933
# Business Entity Type 2    0.082647
# Mobile                    0.081967
# Religion                  0.081081
# Housing                   0.078313
# Other                     0.077901
# Industry: type 6          0.075000
# Kindergarten              0.071854
# Medicine                  0.071759
# Telecom                   0.071111
# Industry: type 7          0.068410
# Hotel                     0.066158
# Advertising               0.065789
# Government                0.065727
# Industry: type 5          0.064655
# Transport: type 2         0.064118
# Industry: type 9          0.062500
# Electricity               0.060109
# Services                  0.059649
# Trade: type 1             0.059259
# Trade: type 2             0.057183
# XNA                       0.055537
# Military                  0.053346
# Industry: type 2          0.052326
# School                    0.051913
# University                0.051878
# Bank                      0.051383
# Trade: type 6             0.044177
# Security Ministries       0.043651
# Police                    0.042827
# Industry: type 12         0.039216
# Transport: type 1         0.038961
# Trade: type 4             0.035714
# Insurance                 0.023256
# Name: Default, dtype: float64
#
# Counts:
# Type_Organization
# Business Entity Type 3    29888
# XNA                       21085
# Self-employed             14725
# Other                      6290
# Medicine                   4320
# Business Entity Type 2     4126
# Government                 3971
# School                     3371
# Trade: type 7              2979
# Kindergarten               2686
# Construction               2623
# Business Entity Type 1     2313
# Transport: type 4          2076
# Trade: type 3              1338
# Security                   1284
# Industry: type 9           1280
# Industry: type 3           1235
# Housing                    1162
# Military                   1031
# Bank                       1012
# Agriculture                1011
# Industry: type 11           999
# Police                      934
# Postal                      834
# Transport: type 2           811
# Security Ministries         756
# Trade: type 2               717
# Restaurant                  710
# Services                    570
# University                  559
# Transport: type 3           501
# Industry: type 7            497
# Industry: type 1            401
# Hotel                       393
# Electricity                 366
# Industry: type 4            337
# Trade: type 6               249
# Industry: type 5            232
# Telecom                     225
# Insurance                   215
# Emergency                   207
# Industry: type 2            172
# Realtor                     156
# Industry: type 12           153
# Advertising                 152
# Trade: type 1               135
# Culture                     131
# Mobile                      122
# Legal Services              119
# Cleaning                    118
# Transport: type 1            77
# Industry: type 6             40
# Industry: type 10            40
# Religion                     37
# Industry: type 13            35
# Trade: type 4                28
# Trade: type 5                12
# Industry: type 8             10
# Name: count, dtype: int64
# ==================== Own_House_Age_Missing ====================
# Own_House_Age_Missing
# 1    0.085336
# 0    0.072077
# Name: Default, dtype: float64
#
# Counts:
# Own_House_Age_Missing
# 1    80095
# 0    41761
# Name: count, dtype: int64
# ==================== Score_Source_1_missing ====================
# Score_Source_1_missing
# 1    0.086192
# 0    0.073782
# Name: Default, dtype: float64
#
# Counts:
# Score_Source_1_missing
# 1    68835
# 0    53021
# Name: count, dtype: int64
# ==================== Social_Circle_Default_missing ====================
# Social_Circle_Default_missing
# 1    0.091623
# 0    0.069600
# Name: Default, dtype: float64
#
# Counts:
# Social_Circle_Default_missing
# 1    61928
# 0    59928
# Name: count, dtype: int64
# ==================== Score_Source_3_missing ====================
# Score_Source_3_missing
# 1    0.088626
# 0    0.078570
# Name: Default, dtype: float64
#
# Counts:
# Score_Source_3_missing
# 0    94934
# 1    26922
# Name: count, dtype: int64
# ==================== Credit_Bureau_missing ====================
# Credit_Bureau_missing
# 1    0.098436
# 0    0.077626
# Name: Default, dtype: float64
#
# Counts:
# Credit_Bureau_missing
# 0    103316
# 1     18540
# Name: count, dtype: int64

# %% [markdown]
# These all seem fine. We can understand visually which category for each column is more likely to default.
# No further comments.

# %% [markdown]
# #### Feature Strength Monitoring - AUC

# %%
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
auc_scores_num = {}

for col in numeric_cols:
    print(col, "done")
    X = df[[col]].fillna(0)  # simple handling
    y = df['Default']

    # scale if needed
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # logistic regression
    model = LogisticRegression()
    model.fit(X_scaled, y)
    preds = model.predict_proba(X_scaled)[:,1]

    auc = roc_auc_score(y, preds)
    auc_scores_num[col] = auc

# Sort
sorted_auc_nums = dict(sorted(auc_scores_num.items(), key=lambda x: x[1], reverse=True))
sorted_auc_nums
# Out:
# Client_Income done
# Child_Count done
# Credit_Amount done
# Loan_Annuity done
# Population_Region_Relative done
# Age_Days done
# Employed_Days done
# Registration_Days done
# ID_Days done
# Own_House_Age done
# Client_Family_Members done
# Client_City_Rating done
# Application_Process_Day done
# Application_Process_Hour done
# Score_Source_1 done
# Score_Source_2 done
# Score_Source_3 done
# Social_Circle_Default done
# Phone_Change done
# Credit_Bureau done
# {'Score_Source_2': 0.6468401358988272,
#  'Score_Source_3': 0.6429316351833487,
#  'Employed_Days': 0.5870923717909715,
#  'Age_Days': 0.5767613519638224,
#  'Score_Source_1': 0.5759833924748894,
#  'ID_Days': 0.5571252907718166,
#  'Phone_Change': 0.5564516166402235,
#  'Client_City_Rating': 0.5471933447877151,
#  'Social_Circle_Default': 0.5470931872989203,
#  'Registration_Days': 0.5382798256786241,
#  'Population_Region_Relative': 0.529913442758939,
#  'Application_Process_Hour': 0.523091661184568,
#  'Client_Income': 0.5201987181490042,
#  'Child_Count': 0.5188556074802184,
#  'Credit_Amount': 0.5184796350104536,
#  'Credit_Bureau': 0.5118346322176812,
#  'Client_Family_Members': 0.5089771129503311,
#  'Application_Process_Day': 0.5057632784641939,
#  'Loan_Annuity': 0.4998437866548685,
#  'Own_House_Age': 0.48667219385725735}

# %%
auc_scores_cat = {}

for col in categorical_cols:
    print(col, "done")
    
    X = df[[col]].copy()
    y = df['Default']

    # temporary label encoding
    le = LabelEncoder()
    try:
        X_encoded = le.fit_transform(X[col])
    except:
        X_encoded = X[col].astype(str)
        X_encoded = le.fit_transform(X_encoded)

    X_encoded = X_encoded.reshape(-1,1)

    model = LogisticRegression()
    model.fit(X_encoded, y)
    preds = model.predict_proba(X_encoded)[:,1]

    auc = roc_auc_score(y, preds)
    auc_scores_cat[col] = auc

sorted_auc_cats = dict(sorted(auc_scores_cat.items(), key=lambda x: x[1], reverse=True))
sorted_auc_cats
# Out:
# Car_Owned done
# Bike_Owned done
# Active_Loan done
# House_Own done
# Accompany_Client done
# Client_Income_Type done
# Client_Education done
# Client_Marital_Status done
# Client_Gender done
# Loan_Contract_Type done
# Client_Housing_Type done
# Homephone_Tag done
# Workphone_Working done
# Client_Occupation done
# Client_Permanent_Match_Tag done
# Client_Contact_Work_Tag done
# Type_Organization done
# Own_House_Age_Missing done
# Score_Source_1_missing done
# Social_Circle_Default_missing done
# Score_Source_3_missing done
# Credit_Bureau_missing done
# {'Client_Education': 0.5482400519150201,
#  'Client_Gender': 0.543835233950645,
#  'Client_Income_Type': 0.5397790984569149,
#  'Social_Circle_Default_missing': 0.5370573159671037,
#  'Type_Organization': 0.5295134747861932,
#  'Workphone_Working': 0.5211844399179053,
#  'Client_Permanent_Match_Tag': 0.5207960992585348,
#  'Score_Source_1_missing': 0.5205355443328978,
#  'Own_House_Age_Missing': 0.5201090698580495,
#  'Client_Occupation': 0.5197202662643882,
#  'Client_Contact_Work_Tag': 0.5196925858769974,
#  'Car_Owned': 0.519514655880742,
#  'Credit_Bureau_missing': 0.5180734353345793,
#  'Homephone_Tag': 0.5158619043704802,
#  'Loan_Contract_Type': 0.5142957568571893,
#  'Score_Source_3_missing': 0.5116533057074462,
#  'Client_Marital_Status': 0.5091174994743474,
#  'Accompany_Client': 0.506848329790435,
#  'House_Own': 0.5005199441274131,
#  'Bike_Owned': 0.5003777054128205,
#  'Active_Loan': 0.4999327684292633,
#  'Client_Housing_Type': 0.4965513490093403}
